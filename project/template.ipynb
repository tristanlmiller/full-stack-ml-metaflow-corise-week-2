# %% [markdown]
# # Week 2 Project: Refining the Art of Sentiment Analysis at ModaMetric
#
# Welcome to Week 2! The ModaMetric team is still buzzing from the achievements of last week. You've shown them the power of Metaflow and the potential of machine learning. However, there's more to explore, more to refine.
#
# Once again, we’ll delve into the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), the dataset that helped us unlock valuable insights for ModaMetric. Your mission is to further refine the sentiment analysis process, enabling ModaMetric to better understand the sentiments embedded in the customer reviews.
#
# ## Task 1: Orchestrating the Dance of Sentiment Analysis Models with Metaflow
#
# In this task, you'll utilize Metaflow to train two sentiment analysis models: the baseline "majority class" classifier and your own custom model. The models will be trained simultaneously, flexing the power of Metaflow. Your task also involves tweaking the models' hyperparameters for optimal performance. Finally, you'll analyze the performance of these models using Metaflow's Client API. Here's how you'll proceed:
#
# ### Step 1: Constructing the Sentiment Analysis Workflows
# Your first task is to construct the Metaflow workflows. Begin with the baseline "majority class" classifier and then move on to your custom model. Make sure your custom model includes steps for data preprocessing, model training, and evaluation. Feel free to use techniques from Week 1 and any other [resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you find useful.
#
# ### Step 2: Parallel Training of Models
# Having built the models, you'll use Metaflow to train them simultaneously. The race is on - can the custom model outshine the baseline? If you find yourself in a bind, you might find the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch) useful.
#
# ### Step 3: The Hyperparameters Experiment
# Once you've trained the models, it's time for some fine-tuning. Experiment with different hyperparameters such as learning rate, batch size, and number of epochs. Record the performance of each model under different hyperparameter combinations as Data Artifacts in Metaflow.
#
# ### Step 4: Results Analysis
# With the experiments complete, it's time to analyze the results. Use Metaflow's Client API to fetch the data and create visualizations to compare the models' performances. The goal is to identify the best hyperparameters for each model.
#
# By completing this task, you're not only refining the sentiment analysis process at ModaMetric but also honing your own skills in orchestrating complex machine learning workflows using Metaflow.

# %%
from collections import Counter
import pandas as pd
import numpy as np
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
import string
from sklearn.model_selection import train_test_split

# You can style your plots here, but it is not part of the project.
YELLOW = "#FFBC00"
GREEN = "#37795D"
PURPLE = "#5460C0"
BACKGROUND = "#F4EBE6"
colors = [GREEN, PURPLE]
custom_params = {
    "axes.spines.right": False,
    "axes.spines.top": False,
    "axes.facecolor": BACKGROUND,
    "figure.facecolor": BACKGROUND,
    "figure.figsize": (8, 8),
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style="ticks", rc=custom_params)

# %%
def labeling_function(row):
    """
    A function to derive labels from the user's review data.
    """
    #return positive class if rating is 5, since that makes it a mostly balanced binary classification
    return (row['rating'] > 4) + 0

# %%
# TODO: load the data.
df = pd.read_csv('../data/Womens Clothing E-Commerce Reviews.csv',index_col=0)

# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df["review"] = df["review_text"].astype("str")
_has_review_df = df[df["review_text"] != "nan"]
reviews = _has_review_df["review_text"]
labels = _has_review_df.apply(labeling_function, axis=1)
df = pd.DataFrame({"label": labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({"review": reviews, "label": labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
# TODO: build the majority class baseline model.
# TODO: find the majority class in the labels. 🤔
# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
# Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html
df['label'].value_counts()
# Out:
# 1    12540
# 0    10101
# Name: label, dtype: int64

# %%
# %%writefile model.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

class NbowModel:
    def __init__(self, vocab_sz):
        self.vocab_sz = vocab_sz

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=0.005,
            max_df=0.75,
            stop_words="english",
            strip_accents="ascii",
            max_features=self.vocab_sz,
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), name="input")
        x = layers.Dropout(0.10)(inputs)
        x = layers.Dense(
            15,
            activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
        )(x)
        predictions = layers.Dense(
            1,
            activation="sigmoid",
        )(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=0.002)
        self.model.compile(
            loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"]
        )

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=32, epochs=10, validation_split=0.2)

    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)

    def eval_acc(self, X, labels, threshold=0.5):
        return accuracy_score(labels, self.predict(X) > threshold)

    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels, self.predict(X))

    @property
    def model_dict(self):
        return {"vectorizer": self.cv, "model": self.model}

    @classmethod
    def from_dict(cls, model_dict):
        "Get Model from dictionary"
        nbow_model = cls(len(model_dict["vectorizer"].vocabulary_))
        nbow_model.model = model_dict["model"]
        nbow_model.cv = model_dict["vectorizer"]
        return nbow_model
# Out:
# Overwriting model.py

# %%
from model import NbowModel
from sklearn.metrics import accuracy_score, roc_auc_score

model = NbowModel(vocab_sz=300)
model.fit(X=traindf["review"], y=traindf["label"])
# Out:
# 2023-10-27 20:59:19.985987: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (18112,)
# Absolutely wonderful - silky and sexy and comfortable
# Epoch 1/10
# 453/453 [==============================] - 2s 2ms/step - loss: 0.5617 - accuracy: 0.7266 - val_loss: 0.5116 - val_accuracy: 0.7629
# Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5157 - accuracy: 0.7602 - val_loss: 0.5083 - val_accuracy: 0.7651
# Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5037 - accuracy: 0.7618 - val_loss: 0.5073 - val_accuracy: 0.7698
# Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4954 - accuracy: 0.7703 - val_loss: 0.5021 - val_accuracy: 0.7704
# Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4882 - accuracy: 0.7760 - val_loss: 0.5068 - val_accuracy: 0.7670
# Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4832 - accuracy: 0.7784 - val_loss: 0.5054 - val_accuracy: 0.7665
# Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4755 - accuracy: 0.7865 - val_loss: 0.5063 - val_accuracy: 0.7659
# Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4685 - accuracy: 0.7873 - val_loss: 0.5057 - val_accuracy: 0.7693
# Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4646 - accuracy: 0.7894 - val_loss: 0.5084 - val_accuracy: 0.7701
# Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4583 - accuracy: 0.7962 - val_loss: 0.5187 - val_accuracy: 0.7618
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 model = NbowModel(vocab_sz=300)
#       5 model.fit(X=traindf["review"], y=traindf["label"])
# ----> 6 predictions = model.predict(self.valdf['review'])
#       7 acc = accuracy_score(self.valdf["label"], predictions)
#       8 scores = model.predict_proba(self.valdf['review'])[:,1]
#
# NameError: name 'self' is not defined

# %%
valdf = valdf.reset_index(drop=True)
predictions = model.predict(valdf['review'])>0.5
acc = accuracy_score(valdf["label"], predictions)
scores = model.predict(valdf['review'])
rocauc = roc_auc_score(valdf["label"], scores)
# Out:
# (4529,)
# I've had my eye on this for a while. went into my local retailer to try it on. tried on s and xs. it fit the same, not much different. the color is great. will go with so many things however i have a larger bust 34d-dd and am short wasted, generally wearing petite in skirts because of it. it sort of belled at the bottom, peplum"ish" which made it look like my bust drooped to my waste. not flattering on me. i'm 5'3ish, 118# and generally wear 4 in tops. it felt like it would stretch out as the day
# 142/142 [==============================] - 0s 910us/step
# (4529,)
# I've had my eye on this for a while. went into my local retailer to try it on. tried on s and xs. it fit the same, not much different. the color is great. will go with so many things however i have a larger bust 34d-dd and am short wasted, generally wearing petite in skirts because of it. it sort of belled at the bottom, peplum"ish" which made it look like my bust drooped to my waste. not flattering on me. i'm 5'3ish, 118# and generally wear 4 in tops. it felt like it would stretch out as the day
# 142/142 [==============================] - 0s 925us/step

# %%
print(acc,rocauc)
# Out:
# 0.7617575623758004 0.8322393685797511

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import (
    FlowSpec,
    step,
    Flow,
    current,
    Parameter,
    IncludeFile,
    card,
    current,
)
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np
from dataclasses import dataclass

# DONE: Define your labeling function here.
labeling_function = lambda row: (row['rating']>4) + 0


@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None


class BaselineChallenge(FlowSpec):
    split_size = Parameter("split-sz", default=0.2)
    data = IncludeFile("data", default="../data/Womens Clothing E-Commerce Reviews.csv")
    kfold = Parameter("k", default=5)
    scoring = Parameter("scoring", default="accuracy")

    @step
    def start(self):
        import pandas as pd
        import io
        from sklearn.model_selection import train_test_split

        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        # DONE: load the data.
        df = pd.read_csv('../data/Womens Clothing E-Commerce Reviews.csv',index_col=0)
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv').
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df["review"] = df["review_text"].astype("str")
        _has_review_df = df[df["review_text"] != "nan"]
        reviews = _has_review_df["review_text"]
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({"label": labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({"review": reviews, "label": labels})
        traindf, valdf = train_test_split(_df, test_size=self.split_size)
        self.traindf = traindf.reset_index(drop=True)
        self.valdf = valdf.reset_index(drop=True)
        print(f"num of rows in train set: {self.traindf.shape[0]}")
        print(f"num of rows in validation set: {self.valdf.shape[0]}")

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score

        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        # DONE: predict the majority class
        predictions = [1]*self.valdf.shape[0]
        # DONE: return the accuracy_score of these predictions
        acc = accuracy_score(self.valdf["label"], predictions)

        # DONE: return the roc_auc_score of these predictions
        rocauc = roc_auc_score(self.valdf["label"], predictions)
        print("Baseline", params, pathspec, acc, rocauc)
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):
        # DONE: import your model if it is defined in another file.
        from model import NbowModel
        from sklearn.metrics import accuracy_score, roc_auc_score

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation,
        # you will have noticed your model's vocab_sz hyperparameter.
        # Too big of vocab_sz causes an error. Can you explain why?
        self.hyperparam_set = [{"vocab_sz": 100}, {"vocab_sz": 300}, {"vocab_sz": 500}]
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(**params)  # DONE: instantiate your custom model here!

            model.fit(X=self.traindf["review"], y=self.traindf["label"])
            predictions = model.predict(self.valdf['review'])>0.5
            acc = accuracy_score(self.valdf["label"], predictions)
            scores = model.predict(self.valdf['review'])
            rocauc = roc_auc_score(self.valdf["label"], scores)
            
            print(f"NbowModel - vocab_sz: {params['vocab_sz']}",
                    params,
                    pathspec,
                    acc,
                    rocauc,)
            self.results.append(
                ModelResult(
                    f"NbowModel - vocab_sz: {params['vocab_sz']}",
                    params,
                    pathspec,
                    acc,
                    rocauc,
                )
            )

        self.next(self.aggregate)

    @step
    def aggregate(self,inputs):
        self.next(self.end)

    @step
    def end(self):
        pass


if __name__ == "__main__":
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run
# Out:
# Metaflow 2.9.7.2+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file ../data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-10-27 21:09:07.888 Workflow starting (run-id 4), see it in the UI at https://ui-pw-1132357439.outerbounds.dev/BaselineChallenge/4
# 2023-10-27 21:09:08.152 [4/start/14 (pid 3652)] Task is starting.
# 2023-10-27 21:09:11.656 [4/start/14 (pid 3652)] num of rows in train set: 18112
# 2023-10-27 21:09:15.242 [4/start/14 (pid 3652)] num of rows in validation set: 4529
# 2023-10-27 21:09:15.522 [4/start/14 (pid 3652)] Task finished successfully.
# 2023-10-27 21:09:16.037 [4/baseline/15 (pid 3754)] Task is starting.
# 2023-10-27 21:09:16.200 [4/model/16 (pid 3757)] Task is starting.
# 2023-10-27 21:09:18.287 [4/model/16 (pid 3757)] 2023-10-27 21:09:18.287212: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# 2023-10-27 21:09:19.161 [4/baseline/15 (pid 3754)] Baseline Always predict 1 BaselineChallenge/4/baseline/15 0.5506734378449989 0.5
# 2023-10-27 21:09:22.094 [4/model/16 (pid 3757)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-27 21:09:22.094 [4/model/16 (pid 3757)] 2023-10-27 21:09:22.094031: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# 2023-10-27 21:09:22.255 [4/model/16 (pid 3757)] (18112,)
# 2023-10-27 21:09:23.028 [4/baseline/15 (pid 3754)] Task finished successfully.
# 2023-10-27 21:09:23.409 [4/model/16 (pid 3757)] I bought one of these as a gift for a friend and i loved it so much i had to get one for myself! it's beautiful material and has lovely detail, a little sheer so best worn with a cami underneath. probably better for those with not too ample busts as it doesn't have a lot of stretch.
# 2023-10-27 21:09:23.409 [4/model/16 (pid 3757)] Epoch 1/10
# 453/453 [==============================] - 2s 2ms/step - loss: 0.6150 - accuracy: 0.6708 - val_loss: 0.5739 - val_accuracy: 0.711099 - accuracy: 0.50
# 2023-10-27 21:09:24.990 [4/model/16 (pid 3757)] Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5806 - accuracy: 0.7064 - val_loss: 0.5619 - val_accuracy: 0.7196 - accuracy: 0.59
# 2023-10-27 21:09:25.771 [4/model/16 (pid 3757)] Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5761 - accuracy: 0.7123 - val_loss: 0.5616 - val_accuracy: 0.7223 - accuracy: 0.75
# 2023-10-27 21:09:26.588 [4/model/16 (pid 3757)] Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5710 - accuracy: 0.7095 - val_loss: 0.5586 - val_accuracy: 0.7196 - accuracy: 0.75
# 2023-10-27 21:09:27.360 [4/model/16 (pid 3757)] Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5688 - accuracy: 0.7145 - val_loss: 0.5650 - val_accuracy: 0.7193 - accuracy: 0.84
# 2023-10-27 21:09:28.122 [4/model/16 (pid 3757)] Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5630 - accuracy: 0.7161 - val_loss: 0.5611 - val_accuracy: 0.7190 - accuracy: 0.71
# 2023-10-27 21:09:28.881 [4/model/16 (pid 3757)] Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5597 - accuracy: 0.7183 - val_loss: 0.5604 - val_accuracy: 0.7207 - accuracy: 0.59
# 2023-10-27 21:09:29.659 [4/model/16 (pid 3757)] Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5597 - accuracy: 0.7165 - val_loss: 0.5604 - val_accuracy: 0.7176 - accuracy: 0.78
# 2023-10-27 21:09:30.422 [4/model/16 (pid 3757)] Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5570 - accuracy: 0.7232 - val_loss: 0.5603 - val_accuracy: 0.7176 - accuracy: 0.68
# 2023-10-27 21:09:31.180 [4/model/16 (pid 3757)] Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7210 - val_loss: 0.5621 - val_accuracy: 0.7207 - accuracy: 0.65
# 2023-10-27 21:09:32.106 [4/model/16 (pid 3757)] (4529,)
# 2023-10-27 21:09:32.453 [4/model/16 (pid 3757)] These chinos are very well made and has a really good fit. not too tight but a bit more relaxed so depending on the look you are going for, these are great! however, i ordered the bright aqua pair and received a pair that is really more teal. a bit disappointed but i'll live. i'm 5'4" with a 30 inseam without shoes. these hit about half an inch below my ankle when not rolled up twice.
# 142/142 [==============================] - 0s 848us/step] 1/142 [..............................] - ETA: 11
# 2023-10-27 21:09:32.647 [4/model/16 (pid 3757)] (4529,)
# 2023-10-27 21:09:32.915 [4/model/16 (pid 3757)] These chinos are very well made and has a really good fit. not too tight but a bit more relaxed so depending on the look you are going for, these are great! however, i ordered the bright aqua pair and received a pair that is really more teal. a bit disappointed but i'll live. i'm 5'4" with a 30 inseam without shoes. these hit about half an inch below my ankle when not rolled up twice.
# 142/142 [==============================] - 0s 828us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:09:33.089 [4/model/16 (pid 3757)] NbowModel - vocab_sz: 100 {'vocab_sz': 100} BaselineChallenge/4/model/16 0.7127401192316185 0.7805653470048017
# 2023-10-27 21:09:33.120 [4/model/16 (pid 3757)] (18112,)
# 2023-10-27 21:09:34.108 [4/model/16 (pid 3757)] I bought one of these as a gift for a friend and i loved it so much i had to get one for myself! it's beautiful material and has lovely detail, a little sheer so best worn with a cami underneath. probably better for those with not too ample busts as it doesn't have a lot of stretch.
# 2023-10-27 21:09:34.109 [4/model/16 (pid 3757)] Epoch 1/10
# 453/453 [==============================] - 2s 2ms/step - loss: 0.5611 - accuracy: 0.7228 - val_loss: 0.5102 - val_accuracy: 0.764802 - accuracy: 0.59
# 2023-10-27 21:09:35.616 [4/model/16 (pid 3757)] Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5138 - accuracy: 0.7591 - val_loss: 0.5091 - val_accuracy: 0.7568 - accuracy: 0.75
# 2023-10-27 21:09:36.468 [4/model/16 (pid 3757)] Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5004 - accuracy: 0.7626 - val_loss: 0.4986 - val_accuracy: 0.7693 - accuracy: 0.75
# 2023-10-27 21:09:37.332 [4/model/16 (pid 3757)] Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4949 - accuracy: 0.7673 - val_loss: 0.4985 - val_accuracy: 0.7635 - accuracy: 0.68
# 2023-10-27 21:09:38.210 [4/model/16 (pid 3757)] Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4887 - accuracy: 0.7734 - val_loss: 0.4983 - val_accuracy: 0.7668 - accuracy: 0.75
# 2023-10-27 21:09:39.084 [4/model/16 (pid 3757)] Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4819 - accuracy: 0.7740 - val_loss: 0.4987 - val_accuracy: 0.7665 - accuracy: 0.81
# 2023-10-27 21:09:39.948 [4/model/16 (pid 3757)] Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4744 - accuracy: 0.7859 - val_loss: 0.5021 - val_accuracy: 0.7629 - accuracy: 0.71
# 2023-10-27 21:09:40.800 [4/model/16 (pid 3757)] Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4684 - accuracy: 0.7843 - val_loss: 0.5065 - val_accuracy: 0.7615 - accuracy: 0.75
# 2023-10-27 21:09:41.640 [4/model/16 (pid 3757)] Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4610 - accuracy: 0.7903 - val_loss: 0.5142 - val_accuracy: 0.7599 - accuracy: 0.90
# 2023-10-27 21:09:42.479 [4/model/16 (pid 3757)] Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4586 - accuracy: 0.7956 - val_loss: 0.5205 - val_accuracy: 0.7571 - accuracy: 0.84
# 2023-10-27 21:09:43.331 [4/model/16 (pid 3757)] (4529,)
# 2023-10-27 21:09:43.331 [4/model/16 (pid 3757)] These chinos are very well made and has a really good fit. not too tight but a bit more relaxed so depending on the look you are going for, these are great! however, i ordered the bright aqua pair and received a pair that is really more teal. a bit disappointed but i'll live. i'm 5'4" with a 30 inseam without shoes. these hit about half an inch below my ankle when not rolled up twice.
# 142/142 [==============================] - 0s 876us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:09:43.826 [4/model/16 (pid 3757)] (4529,)
# 2023-10-27 21:09:44.108 [4/model/16 (pid 3757)] These chinos are very well made and has a really good fit. not too tight but a bit more relaxed so depending on the look you are going for, these are great! however, i ordered the bright aqua pair and received a pair that is really more teal. a bit disappointed but i'll live. i'm 5'4" with a 30 inseam without shoes. these hit about half an inch below my ankle when not rolled up twice.
# 142/142 [==============================] - 0s 879us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:09:44.287 [4/model/16 (pid 3757)] NbowModel - vocab_sz: 300 {'vocab_sz': 300} BaselineChallenge/4/model/16 0.7573415765069552 0.8273083902594729
# 2023-10-27 21:09:44.317 [4/model/16 (pid 3757)] (18112,)
# 2023-10-27 21:09:45.327 [4/model/16 (pid 3757)] I bought one of these as a gift for a friend and i loved it so much i had to get one for myself! it's beautiful material and has lovely detail, a little sheer so best worn with a cami underneath. probably better for those with not too ample busts as it doesn't have a lot of stretch.
# 2023-10-27 21:09:45.327 [4/model/16 (pid 3757)] Epoch 1/10
# 453/453 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7323 - val_loss: 0.5043 - val_accuracy: 0.766297 - accuracy: 0.56
# 2023-10-27 21:09:46.913 [4/model/16 (pid 3757)] Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5037 - accuracy: 0.7655 - val_loss: 0.4944 - val_accuracy: 0.7748 - accuracy: 0.78
# 2023-10-27 21:09:47.820 [4/model/16 (pid 3757)] Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4927 - accuracy: 0.7732 - val_loss: 0.4922 - val_accuracy: 0.7731 - accuracy: 0.75
# 2023-10-27 21:09:48.722 [4/model/16 (pid 3757)] Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4858 - accuracy: 0.7751 - val_loss: 0.4914 - val_accuracy: 0.7762 - accuracy: 0.90
# 2023-10-27 21:09:49.623 [4/model/16 (pid 3757)] Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4786 - accuracy: 0.7800 - val_loss: 0.4963 - val_accuracy: 0.7753 - accuracy: 0.75
# 2023-10-27 21:09:50.546 [4/model/16 (pid 3757)] Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4703 - accuracy: 0.7857 - val_loss: 0.4969 - val_accuracy: 0.7737 - accuracy: 0.62
# 2023-10-27 21:09:51.472 [4/model/16 (pid 3757)] Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4645 - accuracy: 0.7940 - val_loss: 0.5035 - val_accuracy: 0.7679 - accuracy: 0.84
# 2023-10-27 21:09:52.396 [4/model/16 (pid 3757)] Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4563 - accuracy: 0.7978 - val_loss: 0.5034 - val_accuracy: 0.7701 - accuracy: 0.84
# 2023-10-27 21:09:53.399 [4/model/16 (pid 3757)] Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4504 - accuracy: 0.8025 - val_loss: 0.5117 - val_accuracy: 0.7690 - accuracy: 0.84
# 2023-10-27 21:09:54.331 [4/model/16 (pid 3757)] Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4429 - accuracy: 0.8081 - val_loss: 0.5199 - val_accuracy: 0.7629 - accuracy: 0.87
# 2023-10-27 21:09:55.247 [4/model/16 (pid 3757)] (4529,)
# 2023-10-27 21:09:55.247 [4/model/16 (pid 3757)] These chinos are very well made and has a really good fit. not too tight but a bit more relaxed so depending on the look you are going for, these are great! however, i ordered the bright aqua pair and received a pair that is really more teal. a bit disappointed but i'll live. i'm 5'4" with a 30 inseam without shoes. these hit about half an inch below my ankle when not rolled up twice.
# 142/142 [==============================] - 0s 904us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:09:55.761 [4/model/16 (pid 3757)] (4529,)
# 2023-10-27 21:09:56.050 [4/model/16 (pid 3757)] These chinos are very well made and has a really good fit. not too tight but a bit more relaxed so depending on the look you are going for, these are great! however, i ordered the bright aqua pair and received a pair that is really more teal. a bit disappointed but i'll live. i'm 5'4" with a 30 inseam without shoes. these hit about half an inch below my ankle when not rolled up twice.
# 142/142 [==============================] - 0s 941us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:09:56.237 [4/model/16 (pid 3757)] NbowModel - vocab_sz: 500 {'vocab_sz': 500} BaselineChallenge/4/model/16 0.768160741885626 0.8401846002888504
# 2023-10-27 21:09:59.802 [4/model/16 (pid 3757)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-27 21:10:00.062 [4/model/16 (pid 3757)] Task finished successfully.
# 2023-10-27 21:10:00.579 [4/aggregate/17 (pid 4711)] Task is starting.
# 2023-10-27 21:10:04.302 [4/aggregate/17 (pid 4711)] Task finished successfully.
# 2023-10-27 21:10:04.648 [4/end/18 (pid 4773)] Task is starting.
# 2023-10-27 21:10:07.960 [4/end/18 (pid 4773)] Task finished successfully.
# 2023-10-27 21:10:08.252 Done! See the run in the UI at https://ui-pw-1132357439.outerbounds.dev/BaselineChallenge/4

# %% [markdown]
# ## Task 2: Mastering the Art of Anticipation: Failures and Remedies in ModaMetric's Machine Learning Journey
#
# In this task, your challenge is to step into the role of a foresightful data scientist at ModaMetric, where you'll be anticipating potential pitfalls in the sentiment analysis classifier project. Not just that, but you'll also be charting out strategies to steer clear of these hitches. Here's how you'll navigate through:
#
# ### Step 1: Forecasting Potential Failure Modes
#
# The key to overcoming challenges is to anticipate them. Start by picturing possible failure scenarios from an engineering perspective. For instance, you might think about problems like overfitting to the training data or biases in the data. Remember, the first step to finding a solution is acknowledging the problem.
#
# Aside from overfitting the model may also suffer from data quality issues.  If the model is refit on a scheduled basis, pulling new data from an updated database, that database may experience all sorts of issues when we're not watching it.

# %% [markdown]
# ### Step 2: Strategizing to Mitigate Failure Modes
#
# Having identified the potential obstacles, your next task is to devise counter-strategies. Consider what steps you'd take to address the problem if it arises. For instance, to counter overfitting, you could employ regularization techniques such as L1 or L2 regularization. Think of this step as drawing up a contingency plan.
#
# To counter data quality issues, we might create some tests to ensure that the missing percentage doesn't become too high.  We might also have a static validation set, just in case the evaluation data pulled from the database is compromised.  If something unusual is found, a notification could be automatically generated.

# %% [markdown]
# ### Step 3: Planning Ahead to Dodge Failure Modes
#
# Beyond reactive strategies, you also need a proactive plan. What could you have done at the outset to avoid these potential pitfalls? Could you have collected a more diverse dataset to reduce bias? Or experimented with different model architectures? The goal is to minimize reactive measures and maximize foresight.
#
# This task emphasizes the importance of anticipation in machine learning projects. By identifying possible failure modes and crafting mitigation strategies, you'll be preparing yourself for a smooth-sailing machine learning journey at ModaMetric.
#
# When it comes to data quality, that may not always be in the hands of the data scientist, but rather the data engineering team.  The engineering team should have monitoring to detect when data streams go missing.

# %% [markdown]
# ## Task 3: Bringing ML Results to Life: ModaMetric's Visualization Adventure with MF Cards
#
# It's time for you to go beyond the code and transform data into a visual narrative. As a member of ModaMetric's data science team, your next mission is to enhance the existing flow in your `baseline_challenge.py` file. Add a new layer that gathers the results from all the hyperparameter tuning jobs. But that's not all - you're also going to breathe life into this aggregated data by creating a data visualization using Metaflow cards. Here's what you need to do:
#
# ### Step 1: Extend Your Flow
#
# Your first challenge is to add another level to your existing `baseline_challenge.py` file. This new addition should be able to collate all the outcomes from your various hyperparameter tuning jobs.
#
# ### Step 2: Log Results and Create Data Visualization
#
# Once you've collected the outcomes, it's time to log the results in a structured way. Then, you're going to take this information and create a compelling data visualization using Metaflow cards. Remember, a picture is worth a thousand numbers. With these visual insights, you'll be enabling ModaMetric to understand the performance of your machine learning model in a glance.
#
# This task is your opportunity to blend your technical skills with creative thinking. By visualizing your ML results, you're not only making the data more digestible but also contributing to ModaMetric's data-driven decision-making process.

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import (
    FlowSpec,
    step,
    Flow,
    current,
    Parameter,
    IncludeFile,
    card,
    current,
)
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np
from dataclasses import dataclass

# DONE: Define your labeling function here.
labeling_function = lambda row: (row['rating']>4) + 0


@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None


class BaselineChallenge(FlowSpec):
    split_size = Parameter("split-sz", default=0.2)
    data = IncludeFile("data", default="../data/Womens Clothing E-Commerce Reviews.csv")
    kfold = Parameter("k", default=5)
    scoring = Parameter("scoring", default="accuracy")

    @step
    def start(self):
        import pandas as pd
        import io
        from sklearn.model_selection import train_test_split

        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        # DONE: load the data.
        df = pd.read_csv('../data/Womens Clothing E-Commerce Reviews.csv',index_col=0)
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv').
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files

        # filter down to reviews and labels
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df["review"] = df["review_text"].astype("str")
        _has_review_df = df[df["review_text"] != "nan"]
        reviews = _has_review_df["review_text"]
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({"label": labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({"review": reviews, "label": labels})
        traindf, valdf = train_test_split(_df, test_size=self.split_size)
        self.traindf = traindf.reset_index(drop=True)
        self.valdf = valdf.reset_index(drop=True)
        print(f"num of rows in train set: {self.traindf.shape[0]}")
        print(f"num of rows in validation set: {self.valdf.shape[0]}")

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score

        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        # DONE: predict the majority class
        predictions = [1]*self.valdf.shape[0]
        # DONE: return the accuracy_score of these predictions
        acc = accuracy_score(self.valdf["label"], predictions)

        # DONE: return the roc_auc_score of these predictions
        rocauc = roc_auc_score(self.valdf["label"], predictions)
        print("Baseline", params, pathspec, acc, rocauc)
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):
        # DONE: import your model if it is defined in another file.
        from model import NbowModel
        from sklearn.metrics import accuracy_score, roc_auc_score

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation,
        # you will have noticed your model's vocab_sz hyperparameter.
        # Too big of vocab_sz causes an error. Can you explain why?
        self.hyperparam_set = [{"vocab_sz": 100}, {"vocab_sz": 300}, {"vocab_sz": 500}]
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(**params)  # DONE: instantiate your custom model here!

            model.fit(X=self.traindf["review"], y=self.traindf["label"])
            predictions = model.predict(self.valdf['review'])>0.5
            acc = accuracy_score(self.valdf["label"], predictions)
            scores = model.predict(self.valdf['review'])
            rocauc = roc_auc_score(self.valdf["label"], scores)
            
            print(f"NbowModel - vocab_sz: {params['vocab_sz']}",
                    params,
                    pathspec,
                    acc,
                    rocauc,)
            self.results.append(
                ModelResult(
                    f"NbowModel - vocab_sz: {params['vocab_sz']}",
                    params,
                    pathspec,
                    acc,
                    rocauc,
                )
            )

        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append(
            [
                Markdown(result.name),
                Artifact(result.params),
                Artifact(result.pathspec),
                Artifact(result.acc),
                Artifact(result.rocauc),
            ]
        )
        df["name"].append(result.name)
        df["accuracy"].append(result.acc)
        return rows, df

    @card(type='corise')  # DONE: Set your card type to "corise".
    # I wonder what other card types there are?
    # https://docs.metaflow.org/metaflow/visualizing-results
    # https://github.com/outerbounds/metaflow-card-altair/blob/main/altairflow.py
    @step
    def aggregate(self, inputs):
        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams

        rcParams.update({"figure.autolayout": True})

        rows = []
        violin_plot_df = {"name": [], "accuracy": []}
        for task in inputs:
            if task._name == "model":
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")

        current.card.append(Markdown("# All models from this flow run"))

        # DONE: Add a Table of the results to your card!
        current.card.append(
            Table(data=rows,
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"],
            )
        )

        fig, ax = plt.subplots(1, 1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)

        # DONE: Append the matplotlib fig to the card
        current.card.append(Image.from_matplotlib(fig))

        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots

        self.next(self.end)

    @step
    def end(self):
        pass


if __name__ == "__main__":
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run
# Out:
# Metaflow 2.9.7.2+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file ../data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-10-27 21:26:17.967 Workflow starting (run-id 5), see it in the UI at https://ui-pw-1132357439.outerbounds.dev/BaselineChallenge/5
# 2023-10-27 21:26:18.153 [5/start/20 (pid 5100)] Task is starting.
# 2023-10-27 21:26:21.559 [5/start/20 (pid 5100)] num of rows in train set: 18112
# 2023-10-27 21:26:24.984 [5/start/20 (pid 5100)] num of rows in validation set: 4529
# 2023-10-27 21:26:25.280 [5/start/20 (pid 5100)] Task finished successfully.
# 2023-10-27 21:26:25.666 [5/baseline/21 (pid 5202)] Task is starting.
# 2023-10-27 21:26:25.867 [5/model/22 (pid 5205)] Task is starting.
# 2023-10-27 21:26:27.961 [5/model/22 (pid 5205)] 2023-10-27 21:26:27.961274: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# 2023-10-27 21:26:28.975 [5/baseline/21 (pid 5202)] Baseline Always predict 1 BaselineChallenge/5/baseline/21 0.548244645617134 0.5
# 2023-10-27 21:26:31.651 [5/model/22 (pid 5205)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-27 21:26:31.651 [5/model/22 (pid 5205)] 2023-10-27 21:26:31.651590: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# 2023-10-27 21:26:31.831 [5/model/22 (pid 5205)] (18112,)
# 2023-10-27 21:26:32.648 [5/baseline/21 (pid 5202)] Task finished successfully.
# 2023-10-27 21:26:32.932 [5/model/22 (pid 5205)] I bought a xs in black. i like the weight, texture, and thickness of this fabric. it feels like it smoothes over and holds the lines of my body in well. may be the other reviewer got a pair out of an odd batch, which could mean there are inconsistencies? i would like to see how the color and the stretch holds up with future washes. it would have gotten five stars since if it came in petitte length. but i will pick up a couple of more if it hits sale.
# 2023-10-27 21:26:32.933 [5/model/22 (pid 5205)] Epoch 1/10
# 453/453 [==============================] - 2s 2ms/step - loss: 0.6048 - accuracy: 0.6792 - val_loss: 0.5756 - val_accuracy: 0.705299 - accuracy: 0.56
# 2023-10-27 21:26:34.403 [5/model/22 (pid 5205)] Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5751 - accuracy: 0.7085 - val_loss: 0.5718 - val_accuracy: 0.7080 - accuracy: 0.71
# 2023-10-27 21:26:35.180 [5/model/22 (pid 5205)] Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5686 - accuracy: 0.7165 - val_loss: 0.5681 - val_accuracy: 0.7102 - accuracy: 0.81
# 2023-10-27 21:26:35.938 [5/model/22 (pid 5205)] Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5638 - accuracy: 0.7195 - val_loss: 0.5689 - val_accuracy: 0.7113 - accuracy: 0.65
# 2023-10-27 21:26:36.734 [5/model/22 (pid 5205)] Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5610 - accuracy: 0.7218 - val_loss: 0.5691 - val_accuracy: 0.7063 - accuracy: 0.81
# 2023-10-27 21:26:37.520 [5/model/22 (pid 5205)] Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5582 - accuracy: 0.7243 - val_loss: 0.5664 - val_accuracy: 0.7127 - accuracy: 0.84
# 2023-10-27 21:26:38.321 [5/model/22 (pid 5205)] Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7283 - val_loss: 0.5662 - val_accuracy: 0.7094 - accuracy: 0.78
# 2023-10-27 21:26:39.080 [5/model/22 (pid 5205)] Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5526 - accuracy: 0.7256 - val_loss: 0.5675 - val_accuracy: 0.7063 - accuracy: 0.78
# 2023-10-27 21:26:39.851 [5/model/22 (pid 5205)] Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7310 - val_loss: 0.5700 - val_accuracy: 0.7030 - accuracy: 0.75
# 2023-10-27 21:26:40.609 [5/model/22 (pid 5205)] Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7315 - val_loss: 0.5697 - val_accuracy: 0.7080 - accuracy: 0.68
# 2023-10-27 21:26:41.480 [5/model/22 (pid 5205)] (4529,)
# 2023-10-27 21:26:41.826 [5/model/22 (pid 5205)] Super cute with skinny jeans. true to size. i'm size 4, 138 pounds and 34c got a small
# 142/142 [==============================] - 0s 827us/step] 1/142 [..............................] - ETA: 11
# 2023-10-27 21:26:42.017 [5/model/22 (pid 5205)] (4529,)
# 2023-10-27 21:26:42.289 [5/model/22 (pid 5205)] Super cute with skinny jeans. true to size. i'm size 4, 138 pounds and 34c got a small
# 142/142 [==============================] - 0s 835us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:26:42.461 [5/model/22 (pid 5205)] NbowModel - vocab_sz: 100 {'vocab_sz': 100} BaselineChallenge/5/model/22 0.7151689114594834 0.780491703308795
# 2023-10-27 21:26:42.490 [5/model/22 (pid 5205)] (18112,)
# 2023-10-27 21:26:43.496 [5/model/22 (pid 5205)] I bought a xs in black. i like the weight, texture, and thickness of this fabric. it feels like it smoothes over and holds the lines of my body in well. may be the other reviewer got a pair out of an odd batch, which could mean there are inconsistencies? i would like to see how the color and the stretch holds up with future washes. it would have gotten five stars since if it came in petitte length. but i will pick up a couple of more if it hits sale.
# 2023-10-27 21:26:43.496 [5/model/22 (pid 5205)] Epoch 1/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5533 - accuracy: 0.7304 - val_loss: 0.5159 - val_accuracy: 0.755226 - accuracy: 0.53
# 2023-10-27 21:26:44.994 [5/model/22 (pid 5205)] Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.5075 - accuracy: 0.7597 - val_loss: 0.5120 - val_accuracy: 0.7516 - accuracy: 0.87
# 2023-10-27 21:26:45.828 [5/model/22 (pid 5205)] Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4969 - accuracy: 0.7708 - val_loss: 0.5135 - val_accuracy: 0.7505 - accuracy: 0.65
# 2023-10-27 21:26:46.685 [5/model/22 (pid 5205)] Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4918 - accuracy: 0.7691 - val_loss: 0.5115 - val_accuracy: 0.7499 - accuracy: 0.81
# 2023-10-27 21:26:47.539 [5/model/22 (pid 5205)] Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4816 - accuracy: 0.7765 - val_loss: 0.5139 - val_accuracy: 0.7505 - accuracy: 0.75
# 2023-10-27 21:26:48.434 [5/model/22 (pid 5205)] Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4747 - accuracy: 0.7821 - val_loss: 0.5218 - val_accuracy: 0.7502 - accuracy: 0.78
# 2023-10-27 21:26:49.291 [5/model/22 (pid 5205)] Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4712 - accuracy: 0.7875 - val_loss: 0.5263 - val_accuracy: 0.7477 - accuracy: 0.75
# 2023-10-27 21:26:50.148 [5/model/22 (pid 5205)] Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4617 - accuracy: 0.7936 - val_loss: 0.5250 - val_accuracy: 0.7499 - accuracy: 0.75
# 2023-10-27 21:26:50.982 [5/model/22 (pid 5205)] Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4575 - accuracy: 0.7919 - val_loss: 0.5277 - val_accuracy: 0.7563 - accuracy: 0.84
# 2023-10-27 21:26:51.816 [5/model/22 (pid 5205)] Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4491 - accuracy: 0.8009 - val_loss: 0.5376 - val_accuracy: 0.7461 - accuracy: 0.87
# 2023-10-27 21:26:52.654 [5/model/22 (pid 5205)] (4529,)
# 2023-10-27 21:26:52.654 [5/model/22 (pid 5205)] Super cute with skinny jeans. true to size. i'm size 4, 138 pounds and 34c got a small
# 142/142 [==============================] - 0s 890us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:26:53.196 [5/model/22 (pid 5205)] (4529,)
# 2023-10-27 21:26:53.480 [5/model/22 (pid 5205)] Super cute with skinny jeans. true to size. i'm size 4, 138 pounds and 34c got a small
# 142/142 [==============================] - 0s 849us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:26:53.655 [5/model/22 (pid 5205)] NbowModel - vocab_sz: 300 {'vocab_sz': 300} BaselineChallenge/5/model/22 0.7467432104217266 0.8178425610869454
# 2023-10-27 21:26:53.684 [5/model/22 (pid 5205)] (18112,)
# 2023-10-27 21:26:54.720 [5/model/22 (pid 5205)] I bought a xs in black. i like the weight, texture, and thickness of this fabric. it feels like it smoothes over and holds the lines of my body in well. may be the other reviewer got a pair out of an odd batch, which could mean there are inconsistencies? i would like to see how the color and the stretch holds up with future washes. it would have gotten five stars since if it came in petitte length. but i will pick up a couple of more if it hits sale.
# 2023-10-27 21:26:54.720 [5/model/22 (pid 5205)] Epoch 1/10
# 453/453 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7393 - val_loss: 0.5063 - val_accuracy: 0.759602 - accuracy: 0.62
# 2023-10-27 21:26:56.308 [5/model/22 (pid 5205)] Epoch 2/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4941 - accuracy: 0.7732 - val_loss: 0.5033 - val_accuracy: 0.7681 - accuracy: 0.75
# 2023-10-27 21:26:57.256 [5/model/22 (pid 5205)] Epoch 3/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4770 - accuracy: 0.7842 - val_loss: 0.4990 - val_accuracy: 0.7659 - accuracy: 0.87
# 2023-10-27 21:26:58.197 [5/model/22 (pid 5205)] Epoch 4/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4677 - accuracy: 0.7907 - val_loss: 0.5058 - val_accuracy: 0.7596 - accuracy: 0.75
# 2023-10-27 21:26:59.173 [5/model/22 (pid 5205)] Epoch 5/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4563 - accuracy: 0.7969 - val_loss: 0.5070 - val_accuracy: 0.7673 - accuracy: 0.84
# 2023-10-27 21:27:00.133 [5/model/22 (pid 5205)] Epoch 6/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4504 - accuracy: 0.8021 - val_loss: 0.5155 - val_accuracy: 0.7632 - accuracy: 0.81
# 2023-10-27 21:27:01.050 [5/model/22 (pid 5205)] Epoch 7/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4395 - accuracy: 0.8074 - val_loss: 0.5179 - val_accuracy: 0.7637 - accuracy: 0.81
# 2023-10-27 21:27:01.963 [5/model/22 (pid 5205)] Epoch 8/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4308 - accuracy: 0.8143 - val_loss: 0.5260 - val_accuracy: 0.7673 - accuracy: 0.71
# 2023-10-27 21:27:02.884 [5/model/22 (pid 5205)] Epoch 9/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4226 - accuracy: 0.8245 - val_loss: 0.5303 - val_accuracy: 0.7577 - accuracy: 0.84
# 2023-10-27 21:27:03.807 [5/model/22 (pid 5205)] Epoch 10/10
# 453/453 [==============================] - 1s 2ms/step - loss: 0.4125 - accuracy: 0.8286 - val_loss: 0.5480 - val_accuracy: 0.7530 - accuracy: 0.84
# 2023-10-27 21:27:04.758 [5/model/22 (pid 5205)] (4529,)
# 2023-10-27 21:27:05.090 [5/model/22 (pid 5205)] Super cute with skinny jeans. true to size. i'm size 4, 138 pounds and 34c got a small
# 142/142 [==============================] - 0s 912us/step] 1/142 [..............................] - ETA:
# 2023-10-27 21:27:05.274 [5/model/22 (pid 5205)] (4529,)
# 2023-10-27 21:27:05.560 [5/model/22 (pid 5205)] Super cute with skinny jeans. true to size. i'm size 4, 138 pounds and 34c got a small
# 142/142 [==============================] - 0s 1ms/step5)] 1/142 [..............................] - ETA:
# 2023-10-27 21:27:05.757 [5/model/22 (pid 5205)] NbowModel - vocab_sz: 500 {'vocab_sz': 500} BaselineChallenge/5/model/22 0.7604327666151468 0.8248235607212132
# 2023-10-27 21:27:09.283 [5/model/22 (pid 5205)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-27 21:27:09.552 [5/model/22 (pid 5205)] Task finished successfully.
# 2023-10-27 21:27:10.041 [5/aggregate/23 (pid 6162)] Task is starting.
# 2023-10-27 21:27:14.250 [5/aggregate/23 (pid 6162)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge/5/baseline/21', acc=0.548244645617134, rocauc=0.5)
# 2023-10-27 21:27:14.299 [5/aggregate/23 (pid 6162)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100}, pathspec='BaselineChallenge/5/model/22', acc=0.7151689114594834, rocauc=0.780491703308795)
# 2023-10-27 21:27:14.299 [5/aggregate/23 (pid 6162)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300}, pathspec='BaselineChallenge/5/model/22', acc=0.7467432104217266, rocauc=0.8178425610869454)
# 2023-10-27 21:27:18.118 [5/aggregate/23 (pid 6162)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500}, pathspec='BaselineChallenge/5/model/22', acc=0.7604327666151468, rocauc=0.8248235607212132)
# 2023-10-27 21:27:18.520 [5/aggregate/23 (pid 6162)] Task finished successfully.
# 2023-10-27 21:27:18.941 [5/end/24 (pid 6246)] Task is starting.
# 2023-10-27 21:27:22.050 [5/end/24 (pid 6246)] Task finished successfully.
# 2023-10-27 21:27:22.220 Done! See the run in the UI at https://ui-pw-1132357439.outerbounds.dev/BaselineChallenge/5

# %% [markdown]
# ## Task 4: Exploring Advanced Visualization Opportunities with MF Cards (Optional)
#
# As ModaMetric continues to thrive and grow, it's clear that basic visualizations won't be enough to understand the intricate dynamics of our e-commerce customer sentiment. We want to take our data storytelling to the next level. And you, as a valued member of our data science team, are the perfect person to lead this initiative.
#
# This optional task is an open invitation for you to really explore how you can leverage Metaflow's features to deliver a compelling, multidimensional story.
#
# ### Step 1: Dive Deeper into Hyperparameter Tuning Insights
#
# While we have already visualized the results of the hyperparameter tuning, we believe there's more to unearth. Consider how you might visualize the correlation between specific hyperparameters and model performance, or how different hyperparameter combinations affect the training time.
#
# ### Step 2: Unearth Hidden Trends in Customer Sentiment
#
# ModaMetric prides itself on delivering the best for our customers. Can we use our sentiment analysis data to learn more about our customer preferences? Try to create visualizations that show trends in sentiment across different clothing categories, times of year, or any other dimension you find interesting.
#
# ### Step 3: Explore Advanced Visualization Techniques
#
# Metaflow can accommodate a wide range of data visualization techniques. This is your chance to showcase those advanced skills. Perhaps you could experiment with multi-panel plots, 3D visualizations, or interactive plots that let viewers explore the data for themselves. You can refer to this [blog post](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwjJwOe55pqAAxXA6KACHTZzAsoQFnoECCAQAQ&url=https%3A%2F%2Fouterbounds.com%2Fblog%2Fintegrating-pythonic-visual-reports-into-ml-pipelines%2F&usg=AOvVaw2PY3huULq5xR3yZEQ1s-OL&opi=89978449) for more information about how you may do this.
#
# We're looking forward to seeing where your creativity and technical expertise can lead ModaMetric. Remember, there are no boundaries - the sky's the limit!
